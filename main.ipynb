# %% [markdown]
# ### Importing the Necessary Moduels

# %%
import pandas as pd

# Load the Excel file to inspect its contents
file_path = 'supply_chain_data.xlsx'
excel_data = pd.ExcelFile(file_path)

# Display the sheet names to understand the structure of the data
excel_data.sheet_names
# Out:
# ['OrderList',
#  'FreightRates',
#  'WhCosts',
#  'WhCapacities',
#  'ProductsPerPlant',
#  'VmiCustomers',
#  'PlantPorts']

# %%
# Load data from all sheets into a dictionary of DataFrames
data = {sheet: excel_data.parse(sheet) for sheet in excel_data.sheet_names}

# Display the first few rows of each sheet to understand their structure
{sheet: df.head() for sheet, df in data.items()}
# Out:
# {'OrderList':        Order ID Order Date Origin Port Carrier  TPT Service Level  \
#  0  1.447296e+09 2013-05-26      PORT09   V44_3    1           CRF
#  1  1.447158e+09 2013-05-26      PORT09   V44_3    1           CRF
#  2  1.447139e+09 2013-05-26      PORT09   V44_3    1           CRF
#  3  1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
#  4  1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
#
#     Ship ahead day count  Ship Late Day count   Customer  Product ID  \
#  0                     3                    0  V55555_53     1700106
#  1                     3                    0  V55555_53     1700106
#  2                     3                    0  V55555_53     1700106
#  3                     3                    0  V55555_53     1700106
#  4                     3                    0  V55555_53     1700106
#
#    Plant Code Destination Port  Unit quantity  Weight
#  0    PLANT16           PORT09            808   14.30
#  1    PLANT16           PORT09           3188   87.94
#  2    PLANT16           PORT09           2331   61.20
#  3    PLANT16           PORT09            847   16.16
#  4    PLANT16           PORT09           2163   52.34  ,
#  'FreightRates':   Carrier orig_port_cd dest_port_cd  minm_wgh_qty  max_wgh_qty svc_cd  \
#  0  V444_6       PORT08       PORT09         250.0       499.99    DTD
#  1  V444_6       PORT08       PORT09          65.0        69.99    DTD
#  2  V444_6       PORT08       PORT09          60.0        64.99    DTD
#  3  V444_6       PORT08       PORT09          50.0        54.99    DTD
#  4  V444_6       PORT08       PORT09          35.0        39.99    DTD
#
#     minimum cost    rate mode_dsc  tpt_day_cnt Carrier type
#  0       43.2272  0.7132   AIR               2  V88888888_0
#  1       43.2272  0.7512   AIR               2  V88888888_0
#  2       43.2272  0.7892   AIR               2  V88888888_0
#  3       43.2272  0.8272   AIR               2  V88888888_0
#  4       43.2272  1.0552   AIR               2  V88888888_0  ,
#  'WhCosts':         WH  Cost/unit
#  0  PLANT15   1.415063
#  1  PLANT17   0.428947
#  2  PLANT18   2.036254
#  3  PLANT05   0.488144
#  4  PLANT02   0.477504,
#  'WhCapacities':   Plant ID  Daily Capacity
#  0  PLANT15               11
#  1  PLANT17                8
#  2  PLANT18              111
#  3  PLANT05              385
#  4  PLANT02              138,
#  'ProductsPerPlant':   Plant Code  Product ID
#  0    PLANT15     1698815
#  1    PLANT17     1664419
#  2    PLANT17     1664426
#  3    PLANT17     1672826
#  4    PLANT17     1674916,
#  'VmiCustomers':   Plant Code            Customers
#  0    PLANT02    V5555555555555_16
#  1    PLANT02  V555555555555555_29
#  2    PLANT02         V555555555_3
#  3    PLANT02    V55555555555555_8
#  4    PLANT02          V55555555_9,
#  'PlantPorts':   Plant Code    Port
#  0    PLANT01  PORT01
#  1    PLANT01  PORT02
#  2    PLANT02  PORT03
#  3    PLANT03  PORT04
#  4    PLANT04  PORT05}

# %% [markdown]
# #### Removing whitespaces from the columns of the Freight Rates table

# %%
data['FreightRates']['orig_port_cd'] = data['FreightRates']['orig_port_cd'].str.strip()
data['FreightRates']['dest_port_cd'] = data['FreightRates']['dest_port_cd'].str.strip()
data['FreightRates']['Carrier'] = data['FreightRates']['Carrier'].str.strip()
data['FreightRates']['svc_cd'] = data['FreightRates']['svc_cd'].str.strip()
data['FreightRates']['mode_dsc'] = data['FreightRates']['mode_dsc'].str.strip()

# %%
from pulp import *

# %% [markdown]
# #### Decision Variables x_ki and y_kcpjstm

# %%
# Generate the x_ki variable
x_ki = pulp.LpVariable.dicts(
    "x_ki",
    (
    (k, i)
    for k in data['OrderList'].index[:1] # For every order number in the OrderList table
    for i in data['PlantPorts']['Plant Code'].unique() # For every unique Warehouse/Plant in the PlantPorts table
    ),
    cat = "Binary"
)

# %%
x_ki
# Out:
# {(0, 'PLANT01'): x_ki_(0,_'PLANT01'),
#  (0, 'PLANT02'): x_ki_(0,_'PLANT02'),
#  (0, 'PLANT03'): x_ki_(0,_'PLANT03'),
#  (0, 'PLANT04'): x_ki_(0,_'PLANT04'),
#  (0, 'PLANT05'): x_ki_(0,_'PLANT05'),
#  (0, 'PLANT06'): x_ki_(0,_'PLANT06'),
#  (0, 'PLANT07'): x_ki_(0,_'PLANT07'),
#  (0, 'PLANT08'): x_ki_(0,_'PLANT08'),
#  (0, 'PLANT09'): x_ki_(0,_'PLANT09'),
#  (0, 'PLANT10'): x_ki_(0,_'PLANT10'),
#  (0, 'PLANT11'): x_ki_(0,_'PLANT11'),
#  (0, 'PLANT12'): x_ki_(0,_'PLANT12'),
#  (0, 'PLANT13'): x_ki_(0,_'PLANT13'),
#  (0, 'PLANT14'): x_ki_(0,_'PLANT14'),
#  (0, 'PLANT15'): x_ki_(0,_'PLANT15'),
#  (0, 'PLANT16'): x_ki_(0,_'PLANT16'),
#  (0, 'PLANT17'): x_ki_(0,_'PLANT17'),
#  (0, 'PLANT18'): x_ki_(0,_'PLANT18'),
#  (0, 'PLANT19'): x_ki_(0,_'PLANT19')}

# %%
# Generate the y_kcpjstm variable
y_kcpjstm = pulp.LpVariable.dicts(
    "y_kcpjstm",
    (
        (k, c, p, j, s, t, m)  # Exclude 'k' from FreightRates indexing
        for k in data['OrderList'].index[:1]  # Orders
        for c, group in data['FreightRates'].groupby('Carrier')  # Iterate over each Carrier
        for p, j, s, t, m in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].drop_duplicates().itertuples(index=False)
    ),
    cat="Binary",
)

# %%
len(y_kcpjstm)
# Out:
# 76

# %%
y_kcpjstm
# Out:
# {(0,
#   'V444_0',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   4,
#   'AIR'): y_kcpjstm_(0,_'V444_0',_'PORT02',_'PORT09',_'DTD',_4,_'AIR'),
#  (0,
#   'V444_0',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_0',
#   'PORT04',
#   'PORT09',
#   'DTP',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR'),
#  (0,
#   'V444_0',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_0',
#   'PORT04',
#   'PORT09',
#   'DTP',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR'),
#  (0,
#   'V444_0',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   1,
#   'GROUND'): y_kcpjstm_(0,_'V444_0',_'PORT03',_'PORT09',_'DTD',_1,_'GROUND'),
#  (0,
#   'V444_0',
#   'PORT09',
#   'PORT09',
#   'DTP',
#   0,
#   'GROUND'): y_kcpjstm_(0,_'V444_0',_'PORT09',_'PORT09',_'DTP',_0,_'GROUND'),
#  (0,
#   'V444_0',
#   'PORT09',
#   'PORT09',
#   'DTD',
#   0,
#   'GROUND'): y_kcpjstm_(0,_'V444_0',_'PORT09',_'PORT09',_'DTD',_0,_'GROUND'),
#  (0,
#   'V444_1',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT06',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT06',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT05',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT05',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT02',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_1',
#   'PORT05',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_1',_'PORT05',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT11',
#   'PORT09',
#   'DTD',
#   6,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTD',_6,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT07',
#   'PORT09',
#   'DTD',
#   6,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_6,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT08',
#   'PORT09',
#   'DTD',
#   6,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTD',_6,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   6,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_6,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT11',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT11',
#   'PORT09',
#   'DTP',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTP',_5,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT07',
#   'PORT09',
#   'DTP',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTP',_5,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT08',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT08',
#   'PORT09',
#   'DTP',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTP',_5,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT07',
#   'PORT09',
#   'DTD',
#   4,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_4,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT07',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT02',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_2',
#   'PORT10',
#   'PORT09',
#   'DTP',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTP',_3,_'AIR'),
#  (0,
#   'V444_4',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_4',_'PORT10',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_4',
#   'PORT06',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_4',
#   'PORT06',
#   'PORT09',
#   'DTP',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTP',_2,_'AIR'),
#  (0,
#   'V444_4',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_4',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_4',_'PORT02',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_4',
#   'PORT05',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_4',_'PORT05',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT05',
#   'PORT09',
#   'DTD',
#   4,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTD',_4,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT06',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT02',_'PORT09',_'DTD',_3,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT05',
#   'PORT09',
#   'DTP',
#   3,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTP',_3,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT06',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT06',
#   'PORT09',
#   'DTP',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_2,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT02',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT02',
#   'PORT09',
#   'DTP',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT02',_'PORT09',_'DTP',_2,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT05',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT05',
#   'PORT09',
#   'DTP',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTP',_2,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT06',
#   'PORT09',
#   'DTD',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_1,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT06',
#   'PORT09',
#   'DTP',
#   1,
#   'AIR'): y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_1,_'AIR'),
#  (0,
#   'V444_5',
#   'PORT09',
#   'PORT09',
#   'DTD',
#   1,
#   'GROUND'): y_kcpjstm_(0,_'V444_5',_'PORT09',_'PORT09',_'DTD',_1,_'GROUND'),
#  (0,
#   'V444_5',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   1,
#   'GROUND'): y_kcpjstm_(0,_'V444_5',_'PORT03',_'PORT09',_'DTD',_1,_'GROUND'),
#  (0,
#   'V444_5',
#   'PORT09',
#   'PORT09',
#   'DTP',
#   0,
#   'GROUND'): y_kcpjstm_(0,_'V444_5',_'PORT09',_'PORT09',_'DTP',_0,_'GROUND'),
#  (0,
#   'V444_6',
#   'PORT08',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_6',_'PORT08',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_6',
#   'PORT10',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_6',_'PORT10',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_7',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   2,
#   'GROUND'): y_kcpjstm_(0,_'V444_7',_'PORT03',_'PORT09',_'DTD',_2,_'GROUND'),
#  (0,
#   'V444_8',
#   'PORT09',
#   'PORT09',
#   'DTD',
#   14,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_14,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT11',
#   'PORT09',
#   'DTD',
#   14,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_14,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   14,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   14,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_14,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   14,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_14,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT09',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT11',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   5,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_5,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT09',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT11',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   2,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_2,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT09',
#   'PORT09',
#   'DTD',
#   0,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_0,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT11',
#   'PORT09',
#   'DTD',
#   0,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_0,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT04',
#   'PORT09',
#   'DTD',
#   0,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT02',
#   'PORT09',
#   'DTD',
#   0,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_0,_'AIR'),
#  (0,
#   'V444_8',
#   'PORT03',
#   'PORT09',
#   'DTD',
#   0,
#   'AIR'): y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_0,_'AIR'),
#  (0,
#   'V444_9',
#   'PORT08',
#   'PORT09',
#   'DTD',
#   14,
#   'AIR'): y_kcpjstm_(0,_'V444_9',_'PORT08',_'PORT09',_'DTD',_14,_'AIR')}

# %%
(k, c, p, j, s, t, m) = (0, 'V444_1', 'PORT10', 'PORT09', 'DTD', 5, 'AIR')

# %%
y_kcpjstm[k, c, p, j, s, t, m]
# Out:
# y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_5,_'AIR')

# %%
data['OrderList'].head()
# Out:
#        Order ID Order Date Origin Port Carrier  TPT Service Level  \
# 0  1.447296e+09 2013-05-26      PORT09   V44_3    1           CRF
# 1  1.447158e+09 2013-05-26      PORT09   V44_3    1           CRF
# 2  1.447139e+09 2013-05-26      PORT09   V44_3    1           CRF
# 3  1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
# 4  1.447364e+09 2013-05-26      PORT09   V44_3    1           CRF
#
#    Ship ahead day count  Ship Late Day count   Customer  Product ID  \
# 0                     3                    0  V55555_53     1700106
# 1                     3                    0  V55555_53     1700106
# 2                     3                    0  V55555_53     1700106
# 3                     3                    0  V55555_53     1700106
# 4                     3                    0  V55555_53     1700106
#
#   Plant Code Destination Port  Unit quantity  Weight
# 0    PLANT16           PORT09            808   14.30
# 1    PLANT16           PORT09           3188   87.94
# 2    PLANT16           PORT09           2331   61.20
# 3    PLANT16           PORT09            847   16.16
# 4    PLANT16           PORT09           2163   52.34

# %%
# The first row in the OrderList table has weight = 14.3 which does not match any rows in the Freight Rates table
data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m)].query("minm_wgh_qty <= @data['OrderList'].loc[@k]['Weight'] <= max_wgh_qty")['rate']#.iloc[0] * data['OrderList'].loc[k]['Weight']
# Out:
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/1952414235.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m)].query("minm_wgh_qty <= @data['OrderList'].loc[@k]['Weight'] <= max_wgh_qty")['rate']#.iloc[0] * data['OrderList'].loc[k]['Weight']
# Series([], Name: rate, dtype: float64)

# %% [markdown]
# #### Transportation Cost Variable

# %%
# Define transportation cost
transportation_cost = pulp.lpSum(
    y_kcpjstm[k, c, p, j, s, t, m]
    * max(
        # Minimum cost
        data['FreightRates']
        .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
        .loc[(c, p, j, s, t, m)]['minimum cost'].iloc[0],

        # Rate multiplied by weight
        (
            data['FreightRates']
            .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
            .loc[(c, p, j, s, t, m)]
            .query("minm_wgh_qty <= @data['OrderList'].loc[@k]['Weight'] <= max_wgh_qty")['rate'].iloc[0]
            * data['OrderList'].loc[k]['Weight']
        )
        if not data['FreightRates']
        .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
        .loc[(c, p, j, s, t, m)]
        .query("minm_wgh_qty <= @data['OrderList'].loc[@k]['Weight'] <= max_wgh_qty").empty
        else data['FreightRates']
        .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
        .loc[(c, p, j, s, t, m)]['rate'].mean()
    )
    for k in data['OrderList'].index[:1]
    for c, group in data['FreightRates'].groupby('Carrier')
    for p, j, s, t, m in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']]
    .drop_duplicates().itertuples(index=False)
)
# Out:
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/2533690252.py:12: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']

# %%
len(transportation_cost)
# Out:
# 76

# %%
for k, v in transportation_cost.items():
    print(k, v)
# Out:
# y_kcpjstm_(0,_'V444_0',_'PORT02',_'PORT09',_'DTD',_4,_'AIR') 23.8384
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') 3.4552
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') 1.4992
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') 3.4552
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') 1.4992
# y_kcpjstm_(0,_'V444_0',_'PORT03',_'PORT09',_'DTD',_1,_'GROUND') 231.69432000000003
# y_kcpjstm_(0,_'V444_0',_'PORT09',_'PORT09',_'DTP',_0,_'GROUND') 175.58112
# y_kcpjstm_(0,_'V444_0',_'PORT09',_'PORT09',_'DTD',_0,_'GROUND') 189.88112
# y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_5,_'AIR') 1.5884
# y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_3,_'AIR') 1.5884
# y_kcpjstm_(0,_'V444_1',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') 20.346040000000002
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') 1.202
# y_kcpjstm_(0,_'V444_1',_'PORT05',_'PORT09',_'DTD',_2,_'AIR') 1.73996
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') 1.202
# y_kcpjstm_(0,_'V444_1',_'PORT02',_'PORT09',_'DTD',_1,_'AIR') 33.467200000000005
# y_kcpjstm_(0,_'V444_1',_'PORT05',_'PORT09',_'DTD',_1,_'AIR') 1.73996
# y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTD',_6,_'AIR') 15.2272
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_6,_'AIR') 21.2272
# y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTD',_6,_'AIR') 21.0272
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_6,_'AIR') 15.4272
# y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTD',_5,_'AIR') 15.4272
# y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTP',_5,_'AIR') 7.8272
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTP',_5,_'AIR') 9.6272
# y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTD',_5,_'AIR') 19.0272
# y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTP',_5,_'AIR') 21.0272
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_5,_'AIR') 15.6272
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_4,_'AIR') 21.627200000000002
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_3,_'AIR') 23.0272
# y_kcpjstm_(0,_'V444_2',_'PORT02',_'PORT09',_'DTD',_3,_'AIR') 9.0272
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_3,_'AIR') 17.0272
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTP',_3,_'AIR') 15.2272
# y_kcpjstm_(0,_'V444_4',_'PORT10',_'PORT09',_'DTD',_3,_'AIR') 55.69840108361701
# y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') 18.97896
# y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTP',_2,_'AIR') 18.97896
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') 15.00356
# y_kcpjstm_(0,_'V444_4',_'PORT02',_'PORT09',_'DTD',_1,_'AIR') 18.97896
# y_kcpjstm_(0,_'V444_4',_'PORT05',_'PORT09',_'DTD',_1,_'AIR') 21.3928
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTD',_4,_'AIR') 11.6072
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_3,_'AIR') 7.427200000000001
# y_kcpjstm_(0,_'V444_5',_'PORT02',_'PORT09',_'DTD',_3,_'AIR') 7.187200000000001
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTP',_3,_'AIR') 5.8072
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') 13.667200000000001
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_2,_'AIR') 5.4272
# y_kcpjstm_(0,_'V444_5',_'PORT02',_'PORT09',_'DTD',_2,_'AIR') 7.187200000000001
# y_kcpjstm_(0,_'V444_5',_'PORT02',_'PORT09',_'DTP',_2,_'AIR') 5.3872
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTD',_2,_'AIR') 11.6072
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTP',_2,_'AIR') 7.0072
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_1,_'AIR') 25.4672
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_1,_'AIR') 19.6672
# y_kcpjstm_(0,_'V444_5',_'PORT09',_'PORT09',_'DTD',_1,_'GROUND') 304.28112
# y_kcpjstm_(0,_'V444_5',_'PORT03',_'PORT09',_'DTD',_1,_'GROUND') 91.85748000000001
# y_kcpjstm_(0,_'V444_5',_'PORT09',_'PORT09',_'DTP',_0,_'GROUND') 289.98112
# y_kcpjstm_(0,_'V444_6',_'PORT08',_'PORT09',_'DTD',_2,_'AIR') 43.227199999999996
# y_kcpjstm_(0,_'V444_6',_'PORT10',_'PORT09',_'DTD',_2,_'AIR') 43.227199999999996
# y_kcpjstm_(0,_'V444_7',_'PORT03',_'PORT09',_'DTD',_2,_'GROUND') 1830.7889600000003
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_14,_'AIR') 17.6888
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_14,_'AIR') 11.1112
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') 21.470399999999998
# y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_14,_'AIR') 17.5156
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_14,_'AIR') 19.3644
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_5,_'AIR') 23.54
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_5,_'AIR') 15.1176
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') 27.8012
# y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_5,_'AIR') 23.3096
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_5,_'AIR') 25.438
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_2,_'AIR') 25.584000000000003
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_2,_'AIR') 17.483600000000003
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') 29.8812
# y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_2,_'AIR') 25.3328
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_2,_'AIR') 27.563200000000002
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_0,_'AIR') 27.304000000000002
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_0,_'AIR') 27.7884
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') 31.9612
# y_kcpjstm_(0,_'V444_8',_'PORT02',_'PORT09',_'DTD',_0,_'AIR') 27.0384
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_0,_'AIR') 29.339199999999998
# y_kcpjstm_(0,_'V444_9',_'PORT08',_'PORT09',_'DTD',_14,_'AIR') 231.3072

# %% [markdown]
# #### Warehouse Cost Variable

# %%
warehouse_cost = pulp.lpSum(
    x_ki[k, i] * data['OrderList'].loc[k, 'Unit quantity'] * data['WhCosts'].set_index('WH').loc[i, 'Cost/unit']
    for k in data['OrderList'].index[:1]
    for i in data['WhCosts']['WH']
)

# %%
print(len(warehouse_cost))
for k,v in warehouse_cost.items():
    print(k,v)
# Out:
# 19
# x_ki_(0,_'PLANT15') 1143.3712083636265
# x_ki_(0,_'PLANT17') 346.5888423680831
# x_ki_(0,_'PLANT18') 1645.293037921104
# x_ki_(0,_'PLANT05') 394.4206626981252
# x_ki_(0,_'PLANT02') 385.8228432931957
# x_ki_(0,_'PLANT01') 458.1167574230859
# x_ki_(0,_'PLANT06') 447.7031828816371
# x_ki_(0,_'PLANT10') 398.81417397421984
# x_ki_(0,_'PLANT07') 300.11054143976037
# x_ki_(0,_'PLANT14') 512.5384280653706
# x_ki_(0,_'PLANT16') 1551.2044663447662
# x_ki_(0,_'PLANT12') 624.6904898088517
# x_ki_(0,_'PLANT11') 448.63981068457304
# x_ki_(0,_'PLANT09') 375.7774466854115
# x_ki_(0,_'PLANT03') 418.14152843337314
# x_ki_(0,_'PLANT13') 379.5233017178626
# x_ki_(0,_'PLANT19') 516.9281160125348
# x_ki_(0,_'PLANT08') 422.46869775054705
# x_ki_(0,_'PLANT04') 346.2306624797596

# %%
data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m)]['max_wgh_qty'].max()
# Out:
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/1775648345.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m)]['max_wgh_qty'].max()
# np.float64(99999.99)

# %%
# 7. Restrict warehouses to ship orders only through allowed ports
for k in data['OrderList'].index[:1]:
    for i in data['WhCosts']['WH']:
        # Get the allowed ports for the current warehouse
            allowed_ports = data['PlantPorts'].set_index('Plant Code').loc[i, 'Port']
            print(allowed_ports)
            count = 0
            allowed = 0
            not_allowed = 0
            for c, group in data['FreightRates'].groupby('Carrier'):
                for (p, j, s, t, m) in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].drop_duplicates().itertuples(index=False):
                    count += 1
                    if p in allowed_ports:
                        allowed += 1
                        print(f"{y_kcpjstm[k, c, p, j, s, t, m]} compatible with {x_ki[k, i]}")
                    else:
                         not_allowed +=1
print(count, allowed, not_allowed)
# Out:
# PORT08
# y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTD',_6,_'AIR') compatible with x_ki_(0,_'PLANT15')
# y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT15')
# y_kcpjstm_(0,_'V444_2',_'PORT08',_'PORT09',_'DTP',_5,_'AIR') compatible with x_ki_(0,_'PLANT15')
# y_kcpjstm_(0,_'V444_6',_'PORT08',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT15')
# y_kcpjstm_(0,_'V444_9',_'PORT08',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT15')
# PORT10
# y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_1',_'PORT10',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_6,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_2',_'PORT10',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_4',_'PORT10',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT17')
# y_kcpjstm_(0,_'V444_6',_'PORT10',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT17')
# PORT11
# y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTD',_6,_'AIR') compatible with x_ki_(0,_'PLANT18')
# y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT18')
# y_kcpjstm_(0,_'V444_2',_'PORT11',_'PORT09',_'DTP',_5,_'AIR') compatible with x_ki_(0,_'PLANT18')
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT18')
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT18')
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT18')
# y_kcpjstm_(0,_'V444_8',_'PORT11',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT18')
# PORT06
# y_kcpjstm_(0,_'V444_1',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT05')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_1,_'AIR') compatible with x_ki_(0,_'PLANT05')
# PORT03
# y_kcpjstm_(0,_'V444_0',_'PORT03',_'PORT09',_'DTD',_1,_'GROUND') compatible with x_ki_(0,_'PLANT02')
# y_kcpjstm_(0,_'V444_5',_'PORT03',_'PORT09',_'DTD',_1,_'GROUND') compatible with x_ki_(0,_'PLANT02')
# y_kcpjstm_(0,_'V444_7',_'PORT03',_'PORT09',_'DTD',_2,_'GROUND') compatible with x_ki_(0,_'PLANT02')
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT02')
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT02')
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT02')
# y_kcpjstm_(0,_'V444_8',_'PORT03',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT02')
# Plant Code
# PLANT01    PORT01
# PLANT01    PORT02
# Name: Port, dtype: object
# PORT06
# y_kcpjstm_(0,_'V444_1',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_4',_'PORT06',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT06')
# y_kcpjstm_(0,_'V444_5',_'PORT06',_'PORT09',_'DTP',_1,_'AIR') compatible with x_ki_(0,_'PLANT06')
# Plant Code
# PLANT10    PORT01
# PLANT10    PORT02
# Name: Port, dtype: object
# Plant Code
# PLANT07    PORT01
# PLANT07    PORT02
# Name: Port, dtype: object
# PORT07
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_6,_'AIR') compatible with x_ki_(0,_'PLANT14')
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTP',_5,_'AIR') compatible with x_ki_(0,_'PLANT14')
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_4,_'AIR') compatible with x_ki_(0,_'PLANT14')
# y_kcpjstm_(0,_'V444_2',_'PORT07',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT14')
# PORT09
# y_kcpjstm_(0,_'V444_0',_'PORT09',_'PORT09',_'DTP',_0,_'GROUND') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_0',_'PORT09',_'PORT09',_'DTD',_0,_'GROUND') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_5',_'PORT09',_'PORT09',_'DTD',_1,_'GROUND') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_5',_'PORT09',_'PORT09',_'DTP',_0,_'GROUND') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT16')
# y_kcpjstm_(0,_'V444_8',_'PORT09',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT16')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT12')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT12')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT11')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT11')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT09')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT09')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT03')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT03')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT13')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT13')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT19')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT19')
# PORT04
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_3,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_0',_'PORT04',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_1',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_4',_'PORT04',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_14,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_5,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT08')
# y_kcpjstm_(0,_'V444_8',_'PORT04',_'PORT09',_'DTD',_0,_'AIR') compatible with x_ki_(0,_'PLANT08')
# PORT05
# y_kcpjstm_(0,_'V444_1',_'PORT05',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT04')
# y_kcpjstm_(0,_'V444_1',_'PORT05',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT04')
# y_kcpjstm_(0,_'V444_4',_'PORT05',_'PORT09',_'DTD',_1,_'AIR') compatible with x_ki_(0,_'PLANT04')
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTD',_4,_'AIR') compatible with x_ki_(0,_'PLANT04')
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTP',_3,_'AIR') compatible with x_ki_(0,_'PLANT04')
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTD',_2,_'AIR') compatible with x_ki_(0,_'PLANT04')
# y_kcpjstm_(0,_'V444_5',_'PORT05',_'PORT09',_'DTP',_2,_'AIR') compatible with x_ki_(0,_'PLANT04')
# 76 7 69

# %%
import pulp

# Initialize the optimization model
model = pulp.LpProblem("SupplyChainOptimization", pulp.LpMinimize)

# --- Decision Variables ---
# 1. x_ki: Binary variable for order k assigned to warehouse i
# 2. y_kpjcstm: Binary variable for order k assigned to shipping lane p-j-c-s-t-m
# x_ki = pulp.LpVariable.dicts("x_ki", ((k, i) for k in data['OrderList'].index for i in data['WhCosts']['WH']), cat="Binary")
# y_kpjcstm = pulp.LpVariable.dicts(
#     "y_kpjcstm",
#     (
#         (k, p, j, c, s, t, m)
#         for k in data['OrderList'].index
#         for p in data['PlantPorts']['Port'].unique()
#         for j in data['OrderList']['Destination Port'].unique()
#         for c in data['FreightRates']['Carrier'].unique()
#         for s in data['FreightRates']['svc_cd'].unique()
#         for t in data['FreightRates']['tpt_day_cnt'].unique()
#         for m in data['FreightRates']['mode_dsc'].unique()
#     ),
#     cat="Binary",
# )

# --- Objective Function ---
# Minimize total cost = Warehouse cost + Transportation cost
# warehouse_cost = pulp.lpSum(
#     x_ki[k, i] * data['OrderList'].loc[k, 'Unit quantity'] * data['WhCosts'].set_index('WH').loc[i, 'Cost/unit']
#     for k in data['OrderList'].index
#     for i in data['WhCosts']['WH']
# )

# transportation_cost = pulp.lpSum(
#     y_kpjcstm[k, p, j, c, s, t, m]
#     * max(
#         data['FreightRates'].set_index(['orig_port_cd', 'dest_port_cd', 'Carrier']).loc[(p, j, c), 'minimum cost'],
#         data['FreightRates'].set_index(['orig_port_cd', 'dest_port_cd', 'Carrier']).loc[(p, j, c), 'rate']
#         * data['OrderList'].loc[k, 'Weight'],
#     )
#     for k in data['OrderList'].index
#     for p in data['PlantPorts']['Port']
#     for j in data['OrderList']['Destination Port'].unique()
#     for c in data['FreightRates']['Carrier'].unique()
#     for s in data['FreightRates']['svc_cd'].unique()
#     for t in data['FreightRates']['tpt_day_cnt'].unique()
#     for m in data['FreightRates']['mode_dsc'].unique()
# )

model += warehouse_cost + transportation_cost

# --- Constraints ---
# 1. Each order is assigned to exactly one warehouse
for k in data['OrderList'].index:
    model += pulp.lpSum(x_ki[k, i] for i in data['WhCosts']['WH']) == 1

# 2. Each order is assigned to one shipping lane
for k in data['OrderList'].index:
    model += pulp.lpSum(
        y_kcpjstm[k, c, p, j, s, t, m]
        for c, group in data['FreightRates'].groupby('Carrier')  # Iterate over each Carrier
        for p, j, s, t, m in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].drop_duplicates().itertuples(index=False)
    ) == 1

# 3. Warehouse capacity constraints
for i in data['WhCapacities']['Plant ID']:
    model += pulp.lpSum(x_ki[k, i] for k in data['OrderList'].index) <= data['WhCapacities'].set_index('Plant ID').loc[i, 'Daily Capacity ']

# 4. Shipping lane weight constraints
for (p, j, c, s, t, m) in data['FreightRates'][['orig_port_cd', 'dest_port_cd', 'Carrier', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].itertuples(index=False):
    model += pulp.lpSum(
        y_kpjcstm[k, p, j, c, s, t, m] * data['OrderList'].loc[k, 'Weight'] for k in data['OrderList'].index
    ) <= data['FreightRates'].set_index(['orig_port_cd', 'dest_port_cd', 'Carrier']).loc[(p, j, c), 'max_wgh_qty']

# 5. Product compatibility with warehouses
for k in data['OrderList'].index:
    for i in data['WhCosts']['WH']:
        if data['OrderList'].loc[k, 'Product ID'] not in data['ProductsPerPlant'].set_index('Plant Code').loc[i, 'Product ID']:
            model += x_ki[k, i] == 0

# 6. Customer-warehouse restrictions
for k in data['OrderList'].index:
    for i in data['WhCosts']['WH']:
        # Check if the warehouse-customer combination is in VmiCustomers
        if i in data['VmiCustomers']['Plant Code'].unique():
            allowed_customers = data['VmiCustomers'].set_index('Plant Code').loc[i, 'Customers']
            if data['OrderList'].loc[k, 'Customer'] in allowed_customers:
                model += x_ki[k, i] == 1

# 7. Restrict warehouses to ship orders only through allowed ports
for k in data['OrderList'].index:
    for i in data['WhCosts']['WH']:
        # Get the allowed ports for the current warehouse
        if i in data['PlantPorts']['Plant Code'].unique():
            allowed_ports = data['PlantPorts'].set_index('Plant Code').loc[i, 'Port']
            for p in data['PlantPorts']['Port'].unique():
                if p not in allowed_ports:
                    for j in data['OrderList']['Destination Port'].unique():
                        for c in data['FreightRates']['Carrier'].unique():
                            for s in data['FreightRates']['svc_cd'].unique():
                                for t in data['FreightRates']['tpt_day_cnt'].unique():
                                    for m in data['FreightRates']['mode_dsc'].unique():
                                        # Enforce the constraint
                                        model += y_kpjcstm[k, p, j, c, s, t, m] * x_ki[k, i] == 0


# Specify the path to Gurobi
path_to_Gurobi = '/Library/gurobi1003/macos_universal2/bin/gurobi_cl'

# Solve the problem using Gurobi
model.solve(GUROBI_CMD(path=path_to_Gurobi))


# # Output the results
# status = pulp.LpStatus[model.status]
# objective_value = pulp.value(model.objective)
# (status, objective_value)

# %%
import pulp

# Initialize the optimization model
model = pulp.LpProblem("SupplyChainOptimization", pulp.LpMinimize)

# --- Decision Variables ---
# 1. x_ki: Binary variable for order k assigned to warehouse i
x_ki = pulp.LpVariable.dicts(
    "x_ki",
    (
    (k, i)
    for k in data['OrderList'].index[:1] # For every order number in the OrderList table
    for i in data['PlantPorts']['Plant Code'].unique() # For every unique Warehouse/Plant in the PlantPorts table
    ),
    cat = "Binary"
)

# 2. y_kcpjstm: Binary variable for order k assigned to shipping lane c-p-j-s-t-m
y_kcpjstm = pulp.LpVariable.dicts(
    "y_kcpjstm",
    (
        (k, c, p, j, s, t, m)  # Exclude 'k' from FreightRates indexing
        for k in data['OrderList'].index[:1]  # Orders
        for c, group in data['FreightRates'].groupby('Carrier')  # Iterate over each Carrier
        for p, j, s, t, m in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].drop_duplicates().itertuples(index=False)
    ),
    cat="Binary",
)

# --- Objective Function ---

# Minimize total cost = Warehouse cost + Transportation cost
warehouse_cost = pulp.lpSum(
    x_ki[k, i] * data['OrderList'].loc[k, 'Unit quantity'] * data['WhCosts'].set_index('WH').loc[i, 'Cost/unit']
    for k in data['OrderList'].index[:1]
    for i in data['WhCosts']['WH']
)

transportation_cost = pulp.lpSum(
    y_kcpjstm[k, c, p, j, s, t, m]
    * max(
        # Minimum cost
        data['FreightRates']
        .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
        .loc[(c, p, j, s, t, m)]['minimum cost'].iloc[0],

        # Rate multiplied by weight
        (
            data['FreightRates']
            .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
            .loc[(c, p, j, s, t, m)]
            .query("minm_wgh_qty <= @data['OrderList'].loc[@k]['Weight'] <= max_wgh_qty")['rate'].iloc[0]
            * data['OrderList'].loc[k]['Weight']
        )
        if not data['FreightRates']
        .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
        .loc[(c, p, j, s, t, m)]
        .query("minm_wgh_qty <= @data['OrderList'].loc[@k]['Weight'] <= max_wgh_qty").empty
        else data['FreightRates']
        .set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc'])
        .loc[(c, p, j, s, t, m)]['rate'].mean()
    )
    for k in data['OrderList'].index[:1]
    for c, group in data['FreightRates'].groupby('Carrier')
    for p, j, s, t, m in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']]
    .drop_duplicates().itertuples(index=False)
)

model += warehouse_cost + transportation_cost

# --- Constraints ---
# 1. Each order is assigned to exactly one warehouse
for k in data['OrderList'].index[:1]:
    model += pulp.lpSum(x_ki[k, i] for i in data['WhCosts']['WH']) == 1

# 2. Each order is assigned to one shipping lane
for k in data['OrderList'].index[:1]:
    model += pulp.lpSum(
        y_kcpjstm[k, c, p, j, s, t, m]
        for c, group in data['FreightRates'].groupby('Carrier')  # Iterate over each Carrier
        for p, j, s, t, m in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']]
        .drop_duplicates().itertuples(index=False)
    ) == 1

# 3. Warehouse capacity constraints
for i in data['WhCapacities']['Plant ID']:
    model += pulp.lpSum(x_ki[k, i] for k in data['OrderList'].index[:1]) <= data['WhCapacities'].set_index('Plant ID').loc[i, 'Daily Capacity ']

# 4. Shipping lane weight constraints
for c, group in data['FreightRates'].groupby('Carrier'):
    for (p, j, s, t, m) in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].drop_duplicates().itertuples(index=False):
        model += pulp.lpSum(
            y_kcpjstm[k, c, p, j, s, t, m] * data['OrderList'].loc[k, 'Weight'] for k in data['OrderList'].index[:1]
            ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()

# 5. Product compatibility with warehouses
for k in data['OrderList'].index[:1]:
    for i in data['WhCosts']['WH']:
        products = data['ProductsPerPlant'].set_index('Plant Code').loc[i, 'Product ID']
        products = [products] if not isinstance(products, pd.Series) else products.to_list()
        if data['OrderList'].loc[k, 'Product ID'] not in products:
            model += x_ki[k, i] == 0

# 6. Customer-warehouse restrictions
for k in data['OrderList'].index[:1]:
    for i in data['WhCosts']['WH']:
        # Check if the warehouse-customer combination is in VmiCustomers
        if i in data['VmiCustomers']['Plant Code'].unique():
            allowed_customers = data['VmiCustomers'].set_index('Plant Code').loc[i, 'Customers']
            if data['OrderList'].loc[k, 'Customer'] not in allowed_customers:
                model += x_ki[k, i] == 0

# 7. Restrict warehouses to ship orders only through allowed ports
for k in data['OrderList'].index[:1]:
    for i in data['WhCosts']['WH']:
        # Get the allowed ports for the current warehouse
            allowed_ports = data['PlantPorts'].set_index('Plant Code').loc[i, 'Port']
            for c, group in data['FreightRates'].groubpy('Carrier'):
                for (p, j, s, t, m) in group[['orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']].drop_duplicates().itertuples(index=False):
                    if p not in allowed_ports:
                        # Enforce the constraint
                        model += y_kcpjstm[k, c, p, j, s, t, m] * x_ki[k, i] == 0



# Specify the path to Gurobi
path_to_Gurobi = '/Library/gurobi1003/macos_universal2/bin/gurobi_cl'

# Solve the problem using Gurobi
model.solve(GUROBI_CMD(path=path_to_Gurobi))


# # Output the results
# status = pulp.LpStatus[model.status]
# objective_value = pulp.value(model.objective)
# (status, objective_value)
# Out:
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:59: PerformanceWarning: indexing past lexsort depth may impact performance.
#   else data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:43: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:55: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if not data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['FreightRates']
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# ...
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# /var/folders/s9/cygvrxqn4xd69ndg0hg5k56m0000gn/T/ipykernel_13158/3084980721.py:94: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ) <= data['FreightRates'].set_index(['Carrier', 'orig_port_cd', 'dest_port_cd', 'svc_cd', 'tpt_day_cnt', 'mode_dsc']).loc[(c, p, j, s, t, m), 'max_wgh_qty'].max()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'PLANT19'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 99
#      97 for k in data['OrderList'].index[:1]:
#      98     for i in data['WhCosts']['WH']:
# ---> 99         products = data['ProductsPerPlant'].set_index('Plant Code').loc[i, 'Product ID']
#     100         products = [products] if not isinstance(products, pd.Series) else products.to_list()
#     101         if data['OrderList'].loc[k, 'Product ID'] not in products:
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexing.py:1065, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1061 for i, key in enumerate(tup):
#    1062     if is_label_like(key):
#    1063         # We don't need to check for tuples here because those are
#    1064         #  caught by the _is_nested_tuple_indexer check above.
# -> 1065         section = self._getitem_axis(key, axis=i)
#    1067         # We should never have a scalar section here, because
#    1068         #  _getitem_lowerdim is only called after a check for
#    1069         #  is_scalar_access, which that would be.
#    1070         if section.ndim == self.ndim:
#    1071             # we're in the middle of slicing through a MultiIndex
#    1072             # revise the key wrt to `section` by inserting an _NS
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/Desktop/Projects/Supply Chain Optimization/supply_chain_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'PLANT19'

# %%
products = data['ProductsPerPlant'].set_index('Plant Code').loc[i, 'Product ID']
products = [products] if not isinstance(products, pd.Series) else products.to_list()

if data['OrderList'].loc[k, 'Product ID'] not in products:
    print(True)
else:
    print(False)
# Out:
# True

# %%
data['ProductsPerPlant'].set_index('Plant Code').loc[i, 'Product ID'].tolist()
# Out:
# 1698815

# %%
i
# Out:
# 'PLANT15'
